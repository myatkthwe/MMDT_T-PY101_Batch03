# %% [markdown]
# <a href="https://colab.research.google.com/github/myatkthwe/MMDT_T-PY101_Batch03/blob/main/Myat_Kay_Thwe/Ex4_Looping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The exercises are extracted from A_Practical_Introduction_to_Python_Programming_Heinold.pdf

# %% [markdown]
# Ex 1: Write a program that uses a while loop (not a for loop) to read through a string and print
# the characters of the string one-by-one on separate lines.

# %%
string = "Hello Kay"
index = 0

while index < len(string):
    print(string[index])
    index += 1
# Out:
# H
# e
# l
# l
# o
#
# K
# a
# y

# %% [markdown]
# Ex 2: A good program will make sure that the data its users enter is valid. Write a program that
# asks the user for a weight and converts it from kilograms to pounds. Whenever the user
# enters a weight below 0, the program should tell them that their entry is invalid and then ask
# them again to enter a weight. [Hint: Use a while loop, not an if statement].

# %%
weight = float(input("Enter your weight in kg: "))

while weight < 0:
    print("Your entry is invalid")
    weight = float(input("Enter your weight in kg: "))

print("Your weight in pounds is: ", weight * 2.2)
# Out:
# Enter your weight in kg: -1
# Your entry is invalid
# Enter your weight in kg: 2
# Your weight in pounds is:  4.4

# %% [markdown]
# Ex 3: Write a program that allows the user to enter any number of test scores. The user indicates
# they are done by entering in a negative number. Print how many of the scores are A’s (90 or
# above). Also print out the average

# %%
total_scores = 0
num_scores = 0
num_A_scores = 0

while True:
    test_score = float(input("Enter the test score: "))

    if test_score < 0:
        break

    total_scores += test_score
    num_scores += 1

    if test_score >= 90:
        num_A_scores += 1

if num_scores > 0:
    average = total_scores / num_scores
    print(f"Number of A's: {num_A_scores}")
    print(f"Average score: {average:.2f}")
else:
    print("No scores were entered.")
# Out:
# Enter the test score: 20
# Enter the test score: 50
# Enter the test score: 90
# Enter the test score: 80
# Enter the test score: -10
# Number of A's: 1
# Average score: 60.00

# %% [markdown]
# Ex 4: Write a program that asks the user for a string and a letter. Using a for loop, the
# program should print the index of the first occurrence of that letter and a message if the
# string does not contain the letter.

# %%
string = input("Enter a string: ")
search_letter = input("Enter a letter: ")

found = False
for index, char in enumerate(string):
    if char == search_letter:
        print(f"The first occurrence of '{search_letter}' is at index {index}")
        found = True
        break

if not found:
    print(f"The string '{string}' does not contain the letter '{search_letter}'")
# Out:
# Enter a string: I am 30 years old
# Enter a letter: m
# The first occurrence of 'm' is at index 3

# %% [markdown]
# Ex 5: Write a program in which you have a list that contains seven integers that can be 0 or 1. Find the first zero entry in the list and change it to a 1. If there are no zero entries, print a message saying so.

# %%
my_list = [0,1,1,1,0,0,0,1]

found_zero = False
for i, num in enumerate(my_list):
    if num == 0:
        my_list[i] = 1
        found_zero = True
        break

if found_zero:
    print("List after changing the first zero:", my_list)
else:
    print("No zero entries found in the list.")
# Out:
# List after changing the first zero: [1, 1, 1, 1, 0, 0, 0, 1]
